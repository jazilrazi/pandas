# %%
import pandas as pd
data = {
    "Name": ["Anu", "Ravi", "Meera", "Sam"],
    "Marks": [85, 60, 90, 45],
    "Attendance": [92, 70, 88, 60]
}
df = pd.DataFrame (data)
#lowest to highest (default)
print(df.sort_values('Marks'))
#highest to lowest
print(df.sort_values('Marks',ascending = False))
#sort by name -alphabetically
print(df.sort_values('Name'))
# Sort by multiple columns
print(df.sort_values(['Marks','Attendance']))
# Out:
#     Name  Marks  Attendance
# 3    Sam     45          60
# 1   Ravi     60          70
# 0    Anu     85          92
# 2  Meera     90          88
#     Name  Marks  Attendance
# 2  Meera     90          88
# 0    Anu     85          92
# 1   Ravi     60          70
# 3    Sam     45          60
#     Name  Marks  Attendance
# 0    Anu     85          92
# 2  Meera     90          88
# 1   Ravi     60          70
# 3    Sam     45          60
#     Name  Marks  Attendance
# 3    Sam     45          60
# 1   Ravi     60          70
# 0    Anu     85          92
# 2  Meera     90          88
