# %% [markdown]
# Reading data: read_csv(), read_excel()

# %%
import pandas as pd

#reading tha csv file
df = pd.read_csv("student_mark.csv")
#reading tha excel file
df2 = pd.read_excel("student_mark.excel")

print(df,df2)
