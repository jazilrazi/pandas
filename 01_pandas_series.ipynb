# %% [markdown]
# Series — the 1D data structure

# %%
import pandas as pd
temperature = pd.Series([30,45,34,23,36],index=["Mon", "Tue", "Wed", "Thu", "Fri"])
print(temperature)
# Out:
# Mon    30
# Tue    45
# Wed    34
# Thu    23
# Fri    36
# dtype: int64
